# %%
import os
import warnings
import sys 

from glob import glob

import re
import pandas as pd
import numpy as np
from datetime import datetime
from scipy.stats import kurtosis, skew
import sklearn

import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline 


import pickle
import errno

# %% [markdown]
# ### 1. Load The Data

# %%
df_case_study = pd.read_csv(r'/Users/rohankumar/Desktop/AutoScout24/Case Study/Data/AS24_Case_Study_Data.csv', sep=';', index_col = False)
df_description = pd.read_csv(r'/Users/rohankumar/Desktop/AutoScout24/Case Study/Data/AS24_Data_Description.csv', sep=';', index_col = False)

# %%
df_case_study
# Out:
#        article_id product_tier      make_name  price  first_zip_digit  \
# 0       350625839        Basic     Mitsubishi  16750                5
# 1       354412280        Basic  Mercedes-Benz  35950                4
# 2       349572992        Basic  Mercedes-Benz  11950                3
# 3       350266763        Basic           Ford   1750                6
# 4       355688985        Basic  Mercedes-Benz  26500                3
# ...           ...          ...            ...    ...              ...
# 78316   348704581        Basic          Lexus  15740                8
# 78317   359231940        Basic        Hyundai   2950                6
# 78318   362425932        Basic     Volkswagen   7850                8
# 78319   357164227        Basic         Toyota  13945                5
# 78320   353639932        Basic     Volkswagen  38800                7
#
#        first_registration_year created_date deleted_date  search_views  \
# 0                         2013     24.07.18     24.08.18        3091.0
# 1                         2015     16.08.18     07.10.18        3283.0
# 2                         1998     16.07.18     05.09.18        3247.0
# 3                         2003     20.07.18     29.10.18        1856.0
# 4                         2014     28.08.18     08.09.18         490.0
# ...                        ...          ...          ...           ...
# 78316                     2014     12.07.18     19.10.18        6895.0
# 78317                     2006     28.09.18     23.10.18        1175.0
# 78318                     2014     04.11.18     21.11.18         448.0
# 78319                     2011     04.09.18     02.10.18        1617.0
# 78320                     2018     08.08.18     09.08.18          55.0
#
#        detail_views  stock_days                   ctr
# 0             123.0          30   0.03780329990294403
# 1             223.0          52   0.06792567773378008
# 2             265.0          51    0.0816137973514013
# 3              26.0         101  0.014008620689655173
# 4              20.0          12   0.04081632653061224
# ...             ...         ...                   ...
# 78316         230.0          99   0.03335750543872371
# 78317          16.0          25  0.012936170212765956
# 78318          21.0          16              0.046875
# 78319          29.0          28  0.017934446505875078
# 78320           2.0           1   0.03454545454545454
#
# [78321 rows x 12 columns]

# %%
df_description
# Out:
#                 column name                                        description
# 0                article_id                          unique article identifier
# 1              product_tier                      premium status of the article
# 2                 make_name                       name of the car manufacturer
# 3                     price                               price of the article
# 4           first_zip_digit  first digit of the zip code of the region the ...
# 5   first_registration_year      year of the first registration of the article
# 6              created_date                       creation date of the listing
# 7              deleted_date                       deletion date of the listing
# 8              search_views  number of times the article has been shown as ...
# 9              detail_views    number of times the article has been clicked on
# 10               stock_days  Time in days between the creation of the listi...
# 11                      ctr  Click through rate calculated as the quotient ...

# %% [markdown]
# ### 2. Check for nulls and missing values

# %%
df_missing_values = pd.DataFrame(df_case_study.isnull().sum(),index=None)
df_missing_values['Count'] = df_missing_values[0]
df_missing_values = df_missing_values.drop(columns={0})
df_missing_values.plot.bar(figsize = (12, 6), rot=45)
plt.xlabel('Features', size=14)
plt.ylabel('Count', size=14)
plt.show()

# Percentage of missing values
df_missing_values['Percent Missing Values'] = ((df_missing_values['Count']/len(df_case_study))*100)
print(df_missing_values)
# Out:
#                          Count  Percent Missing Values
# article_id                   0                0.000000
# product_tier                 0                0.000000
# make_name                    0                0.000000
# price                        0                0.000000
# first_zip_digit              0                0.000000
# first_registration_year      0                0.000000
# created_date                 0                0.000000
# deleted_date                 0                0.000000
# search_views                10                0.012768
# detail_views                10                0.012768
# stock_days                   0                0.000000
# ctr                         24                0.030643

# %%
## Let us see what rows have null values 
df_case_study[df_case_study['ctr'].isnull()]
# Out:
#        article_id product_tier      make_name  price  first_zip_digit  \
# 6738    355684985        Basic          Volvo   5950                8
# 10151   363161664        Basic        Renault   4950                3
# 19983   360460901        Basic  Mercedes-Benz    105                7
# 21423   358837372        Basic     Volkswagen   2999                5
# 26122   360460897        Basic  Mercedes-Benz  22445                7
# 27830   358837359        Basic     Volkswagen   2999                5
# 28823   360460890        Basic  Mercedes-Benz  26445                7
# 38923   360471136        Basic           Audi   1500                2
# 43222   360493605        Basic  Mercedes-Benz  37500                3
# 47870   358837344        Basic     Volkswagen   2999                5
# 52291   360460896        Basic  Mercedes-Benz   1194                7
# 57353   350278423        Basic            BMW  10950                9
# 60758   350270138        Basic           Ford   5450                2
# 63577   358837366        Basic     Volkswagen   2999                5
# 65127   358837392        Basic     Volkswagen   2999                5
# 66498   349581063        Basic         Subaru      1                5
# 68584   360460887        Basic           Opel  16445                7
# 69176   360460879        Basic  Mercedes-Benz  30445                7
# 70772   364670935        Basic  Mercedes-Benz   2150                3
# 71083   363908548        Basic        Renault  14500                7
# 71854   363925615        Basic           Fiat   3795                5
# 72408   358837338        Basic     Volkswagen   2999                5
# 72620   359233783        Basic           Audi   1039                4
# 78057   360460880        Basic  Mercedes-Benz    994                7
#
#        first_registration_year created_date deleted_date  search_views  \
# 6738                      2009     28.08.18     28.08.18           0.0
# 10151                     2011     12.11.18     01.03.19           NaN
# 19983                     2004     12.10.18     12.10.18           0.0
# 21423                     2003     24.09.18     24.09.18           NaN
# 26122                     2011     12.10.18     12.10.18           0.0
# 27830                     2003     24.09.18     24.09.18           NaN
# 28823                     2011     12.10.18     12.10.18           0.0
# 38923                     2012     12.10.18     12.10.18           0.0
# 43222                     2002     12.10.18     12.10.18           0.0
# 47870                     2003     24.09.18     24.09.18           NaN
# 52291                     2018     12.10.18     12.10.18           0.0
# 57353                     2006     20.07.18     20.07.18           NaN
# 60758                     2009     20.07.18     26.07.18           NaN
# 63577                     2003     24.09.18     24.09.18           NaN
# 65127                     2003     24.09.18     24.09.18           NaN
# 66498                     2006     16.07.18     11.09.18           NaN
# 68584                     2009     12.10.18     12.10.18           0.0
# 69176                     2014     12.10.18     12.10.18           0.0
# 70772                     2002     28.11.18     29.11.18           0.0
# 71083                     2015     20.11.18     20.11.18           0.0
# 71854                     2011     20.11.18     21.11.18           0.0
# 72408                     2003     24.09.18     24.09.18           NaN
# 72620                     2016     28.09.18     28.09.18           0.0
# 78057                     2014     12.10.18     12.10.18           0.0
#
#        detail_views  stock_days  ctr
# 6738            0.0           0  NaN
# 10151           NaN         109  NaN
# 19983           0.0          -1  NaN
# 21423           NaN           0  NaN
# 26122           0.0           0  NaN
# 27830           NaN           0  NaN
# 28823           0.0           0  NaN
# 38923           0.0           0  NaN
# 43222           0.0           0  NaN
# 47870           NaN           0  NaN
# 52291           0.0           0  NaN
# 57353           NaN          -1  NaN
# 60758           NaN           7  NaN
# 63577           NaN           0  NaN
# 65127           NaN           0  NaN
# 66498           NaN          57  NaN
# 68584           0.0           0  NaN
# 69176           0.0           0  NaN
# 70772           0.0           1  NaN
# 71083           0.0           0  NaN
# 71854           0.0           2  NaN
# 72408           NaN           0  NaN
# 72620           0.0           0  NaN
# 78057           0.0           0  NaN

# %% [markdown]
# <p> The 'ctr' column has 24 null values. We can see that the two columns search_views and detail_views also have non-significant null values and therefore we can safely discard these particular rows.</p>

# %%
df_case_study_new = df_case_study.dropna(axis = 0)
df_case_study_new = df_case_study_new.reset_index(drop=True)
print(df_case_study_new.isnull().sum())

print('\n')
print("Shape of the old dataset is:{}".format(df_case_study.shape))
print("Shape of the new dataset is:{}".format(df_case_study_new.shape))
# Out:
# article_id                 0
# product_tier               0
# make_name                  0
# price                      0
# first_zip_digit            0
# first_registration_year    0
# created_date               0
# deleted_date               0
# search_views               0
# detail_views               0
# stock_days                 0
# ctr                        0
# dtype: int64
#
#
# Shape of the old dataset is:(78321, 12)
# Shape of the new dataset is:(78297, 12)

# %% [markdown]
# ### 3. Lets us look at the summary of our data

# %%
df_case_study_new.describe()
# Out:
#          article_id          price  first_zip_digit  first_registration_year  \
# count  7.829700e+04   78297.000000     78297.000000             78297.000000
# mean   3.574864e+08   15069.670358         4.631876              2011.090336
# std    5.076809e+06   16375.598837         2.354368                 6.538638
# min    3.472324e+08      50.000000         1.000000              1924.000000
# 25%    3.536387e+08    5750.000000         3.000000              2008.000000
# 50%    3.585479e+08   10909.000000         5.000000              2013.000000
# 75%    3.614817e+08   18890.000000         7.000000              2015.000000
# max    3.647040e+08  249888.000000         9.000000              2106.000000
#
#        search_views  detail_views    stock_days
# count   78297.00000  78297.000000  78297.000000
# mean     2297.91333     93.486583     35.995070
# std      6339.52668    228.042547     32.213083
# min         1.00000      0.000000     -3.000000
# 25%       368.00000     13.000000     10.000000
# 50%       920.00000     36.000000     25.000000
# 75%      2234.00000     94.000000     55.000000
# max    608754.00000  13926.000000    127.000000

# %% [markdown]
# <p>We can clearly see that apart from all the string and date columns, the <b>click-through-rate(ctr)</b> is missing. This needs to be investigated!</p>
#
# <p> Also, if we look at the <b>max first_registration_year</b> in the above view, we can see the value to be 2106. We will need to get rid of the years after 2020.</p>

# %%
# Let us convert the ctr column into float type
try:
    df_case_study_new['ctr'] = df_case_study_new['ctr'].astype(float)
except:
    print('Could not convert due to ambiguous value')
# Out:
# Could not convert due to ambiguous value

# %%
# Let us match all the object elements and see if there are other values than just numeric
i = 0
list_numbers = []
while(i<df_case_study_new.shape[0]):
    if(bool(re.search(r"^\d*\.?\d*$", str(df_case_study_new['ctr'].loc[i])))== False):
        list_numbers.append(df_case_study_new['ctr'].loc[i])
        print(df_case_study_new['ctr'].loc[i])
    i += 1
# Out:
# 27.624.309.392.265.100
# 4.086.021.505.376.340
# 30.066.815.144.766.100
# 5.126.118.795.768.910
# 1.485.148.514.851.480
# 49.729.729.729.729.700
# 3.561.643.835.616.430
# 19.169.329.073.482.400
# 43.058.350.100.603.600
# 16.423.082.718.095.500
# 17.298.937.784.522.000
# 23.692.810.457.516.300
# 18.787.878.787.878.700
# 25.096.525.096.525.000
# 21.399.456.521.739.100
# 16.666.666.666.666.600
# 29.850.746.268.656.700
# 5.551.948.051.948.050
# 41.534.988.713.318.200
# 11.155.913.978.494.600
# 2.287.390.029.325.510
# 10.317.460.317.460.300
# 3.834.416.223.666.070
# 22.727.272.727.272.700
# 5.369.565.217.391.300
# 9.677.419.354.838.700
# 57.017.543.859.649.100
# 2.608.503.100.088.570
# 2.271.006.813.020.430
# 5.202.312.138.728.320
# 52.424.545.844.657.400
# 2.867.570.385.818.560
# 5.101.851.851.851.850
# 5.429.417.571.569.590
# 11.794.500.723.589.000
# 18.333.333.333.333.300
# 3.078.556.263.269.630
# 13.796.849.538.294.400
# 5.523.429.710.867.390
# 30.805.687.203.791.400
# 6.001.690.617.075.230
# 3.838.771.593.090.210
# 33.738.191.632.928.400
# 3.245.686.113.393.590
# 3.703.703.703.703.700
# 01. Apr
# 6.719.056.974.459.720
# 4.545.454.545.454.540
# 4.953.429.297.205.750
# 31.758.056.758.056.700
# 4.973.221.117.061.970
# 5.272.013.460.459.890
# 45.243.128.964.059.100
# 4.292.929.292.929.290
# 11.920.529.801.324.500
# 10.508.474.576.271.100
# 18.905.253.901.956.400
# 7.886.435.331.230.280
# 16.949.152.542.372.800
# 6.493.506.493.506.490
# 2.010.487.059.417.320
# 52.287.581.699.346.400
# 14.511.873.350.923.400
# 57.926.829.268.292.600
# 17.543.859.649.122.800
# 33.898.305.084.745.700
# 25.333.333.333.333.300
# 1.485.148.514.851.480
# 18.569.087.930.092.800
# 8.695.652.173.913.040
# 21.978.021.978.021.900
# 24.081.115.335.868.100
# 14.957.264.957.264.900
# 16.938.039.558.518.100
# 4.291.845.493.562.230
# 6.785.714.285.714.280
# 7.547.169.811.320.750
# 7.574.884.792.626.720
# 23.525.280.898.876.400
# 2.883.720.930.232.550
# 4.199.855.177.407.670
# 34.981.905.910.735.800

# %% [markdown]
# <p>We can see from the above list that the ctr has some strange values! 01 April which is weirdly present in the dataset!</p>

# %%
## Let us create the dataset of values in the ctr that are absurd
absurd_dataset=pd.DataFrame()
for element in list_numbers:
    absurd_dataset = absurd_dataset.append(df_case_study_new[df_case_study_new['ctr'] == element])
absurd_dataset
# Out:
#        article_id product_tier   make_name  price  first_zip_digit  \
# 849     361161145        Basic  Volkswagen  32450                6
# 1649    360100841        Basic        Opel   4949                8
# 3885    353638718        Basic  Volkswagen   3750                2
# 4169    357115804        Basic     Citroen   8940                2
# 4410    353090123        Basic        Fiat   4250                5
# ...           ...          ...         ...    ...              ...
# 71837   360491257        Basic         BMW   6999                7
# 73032   357159320        Basic        Fiat   3750                2
# 73379   364332664        Basic         Kia   7850                8
# 74845   361183805        Basic      Nissan   6950                2
# 76385   364317161        Basic      Toyota   1900                4
#
#        first_registration_year created_date deleted_date  search_views  \
# 849                       2018     20.10.18     08.11.18        2172.0
# 1649                      2011     08.10.18     31.10.18         930.0
# 3885                      2009     08.08.18     29.08.18         898.0
# 4169                      2012     04.09.18     19.10.18        1229.0
# 4410                      2010     04.08.18     10.08.18         404.0
# ...                        ...          ...          ...           ...
# 71837                     2005     12.10.18     31.12.18        3472.0
# 73032                     2008     04.09.18     05.01.19        2848.0
# 73379                     2011     24.11.18     16.01.19        1075.0
# 74845                     2013     20.10.18     01.12.18        1381.0
# 76385                     1998     24.11.18     01.12.18         829.0
#
#        detail_views  stock_days                     ctr
# 849            60.0          19  27.624.309.392.265.100
# 1649           40.0          23   4.086.021.505.376.340
# 3885           27.0          20  30.066.815.144.766.100
# 4169           63.0          44   5.126.118.795.768.910
# 4410            6.0           6   1.485.148.514.851.480
# ...             ...         ...                     ...
# 71837         263.0          79   7.574.884.792.626.720
# 73032          67.0         123  23.525.280.898.876.400
# 73379          31.0          53   2.883.720.930.232.550
# 74845          58.0          42   4.199.855.177.407.670
# 76385          29.0           7  34.981.905.910.735.800
#
# [84 rows x 12 columns]

# %% [markdown]
# <p> The rows with absurd or strange values in the <b>ctr</b> needs to be dropped since they vary  significantly from the other values in the dataset. These values are significantly higher and I am assuming here that they are inherently incorrect.</p>

# %%
## Dropping the rows using the index in the 'absurd dataset'

df_case_study_new = df_case_study_new.drop(index=absurd_dataset.index)

# Reset the index 
df_case_study_new = df_case_study_new.reset_index(drop=True)
df_case_study_new
# Out:
#        article_id product_tier      make_name  price  first_zip_digit  \
# 0       350625839        Basic     Mitsubishi  16750                5
# 1       354412280        Basic  Mercedes-Benz  35950                4
# 2       349572992        Basic  Mercedes-Benz  11950                3
# 3       350266763        Basic           Ford   1750                6
# 4       355688985        Basic  Mercedes-Benz  26500                3
# ...           ...          ...            ...    ...              ...
# 78210   348704581        Basic          Lexus  15740                8
# 78211   359231940        Basic        Hyundai   2950                6
# 78212   362425932        Basic     Volkswagen   7850                8
# 78213   357164227        Basic         Toyota  13945                5
# 78214   353639932        Basic     Volkswagen  38800                7
#
#        first_registration_year created_date deleted_date  search_views  \
# 0                         2013     24.07.18     24.08.18        3091.0
# 1                         2015     16.08.18     07.10.18        3283.0
# 2                         1998     16.07.18     05.09.18        3247.0
# 3                         2003     20.07.18     29.10.18        1856.0
# 4                         2014     28.08.18     08.09.18         490.0
# ...                        ...          ...          ...           ...
# 78210                     2014     12.07.18     19.10.18        6895.0
# 78211                     2006     28.09.18     23.10.18        1175.0
# 78212                     2014     04.11.18     21.11.18         448.0
# 78213                     2011     04.09.18     02.10.18        1617.0
# 78214                     2018     08.08.18     09.08.18          55.0
#
#        detail_views  stock_days                   ctr
# 0             123.0          30   0.03780329990294403
# 1             223.0          52   0.06792567773378008
# 2             265.0          51    0.0816137973514013
# 3              26.0         101  0.014008620689655173
# 4              20.0          12   0.04081632653061224
# ...             ...         ...                   ...
# 78210         230.0          99   0.03335750543872371
# 78211          16.0          25  0.012936170212765956
# 78212          21.0          16              0.046875
# 78213          29.0          28  0.017934446505875078
# 78214           2.0           1   0.03454545454545454
#
# [78215 rows x 12 columns]

# %% [markdown]
# ### 4. Set appropriate datatypes for each column
#
# This step would allow us to carry on with the further analysis. The datatypes will be set according to column types.

# %%
# Let us drop the article_id column since it has no importance 
df_case_study_new = df_case_study_new.drop(columns={'article_id'})
df_case_study_new
# Out:
#       product_tier      make_name  price  first_zip_digit  \
# 0            Basic     Mitsubishi  16750                5
# 1            Basic  Mercedes-Benz  35950                4
# 2            Basic  Mercedes-Benz  11950                3
# 3            Basic           Ford   1750                6
# 4            Basic  Mercedes-Benz  26500                3
# ...            ...            ...    ...              ...
# 78210        Basic          Lexus  15740                8
# 78211        Basic        Hyundai   2950                6
# 78212        Basic     Volkswagen   7850                8
# 78213        Basic         Toyota  13945                5
# 78214        Basic     Volkswagen  38800                7
#
#        first_registration_year created_date deleted_date  search_views  \
# 0                         2013     24.07.18     24.08.18        3091.0
# 1                         2015     16.08.18     07.10.18        3283.0
# 2                         1998     16.07.18     05.09.18        3247.0
# 3                         2003     20.07.18     29.10.18        1856.0
# 4                         2014     28.08.18     08.09.18         490.0
# ...                        ...          ...          ...           ...
# 78210                     2014     12.07.18     19.10.18        6895.0
# 78211                     2006     28.09.18     23.10.18        1175.0
# 78212                     2014     04.11.18     21.11.18         448.0
# 78213                     2011     04.09.18     02.10.18        1617.0
# 78214                     2018     08.08.18     09.08.18          55.0
#
#        detail_views  stock_days                   ctr
# 0             123.0          30   0.03780329990294403
# 1             223.0          52   0.06792567773378008
# 2             265.0          51    0.0816137973514013
# 3              26.0         101  0.014008620689655173
# 4              20.0          12   0.04081632653061224
# ...             ...         ...                   ...
# 78210         230.0          99   0.03335750543872371
# 78211          16.0          25  0.012936170212765956
# 78212          21.0          16              0.046875
# 78213          29.0          28  0.017934446505875078
# 78214           2.0           1   0.03454545454545454
#
# [78215 rows x 11 columns]

# %%
df_case_study_new.dtypes
# Out:
# product_tier                object
# make_name                   object
# price                        int64
# first_zip_digit              int64
# first_registration_year      int64
# created_date                object
# deleted_date                object
# search_views               float64
# detail_views               float64
# stock_days                   int64
# ctr                         object
# dtype: object

# %%
## Look at the first 5 rows and change the datatype accordingly
import re

def set_datatype(df):
    # select the first 5 rows as samples
    sample_df = df.iloc[:5,:]
        
    i = 0 
    # Run until total number of columns are reached
    while(i< sample_df.shape[1]):
        c,d,e = 0,0,0
        sample_list = sample_df.iloc[:,i].tolist()
        print(sample_list)
        for element in sample_list:
            if(bool(re.search("^[a-zA-Z-\s]*$", str(element))) == True):
                # String counter
                c += 1
            elif(bool(re.search(r"^\d*\.?\d*$", str(element)))== True):
                # Numeric counter
                d += 1
            elif (bool(re.search(r"[0-3]?[0-9].[0-3]?[0-9].(?:[0-9]{2})?[0-9]{2}$", str(element))) == True):
                # Date counter
                e += 1
            else:
                print('Unknown DataType')
            
        # check if c and d equals the length of the dataset
        df = change_datatype(c, d, e, i, df, sample_df) 
        i += 1
    return df
 
# Change the datatype based on the key 
def change_datatype(c, d, e, i, df, sample_df):
    if c == sample_df.shape[0]:
        # Change the datatype to string
        df.iloc[:,i] = df.iloc[:,i].astype(str)
    elif d == sample_df.shape[0]:
        print('inside d')
        # Change the datatype to numeric
        df.iloc[:,i] = df.iloc[:,i].astype(float)
        
    elif e == sample_df.shape[0]:
        # Change the datatype to datetime
        df.iloc[:,i] = pd.to_datetime(df.iloc[:,i], format="%d.%m.%y")
    else:
        print('Datatypes cannot be set')
    return df

if __name__ == '__main__':
    final_df = set_datatype(df_case_study_new)
    print("Successfully set the datatypes")

## The 'first_registration_year' column is now a float datatype. Let's put it to datetime type!

final_df['first_registration_year'] = pd.to_datetime(final_df['first_registration_year'], format = '%Y')
final_df['first_registration_year']
# Out:
# ['Basic', 'Basic', 'Basic', 'Basic', 'Basic']
# ['Mitsubishi', 'Mercedes-Benz', 'Mercedes-Benz', 'Ford', 'Mercedes-Benz']
# [16750, 35950, 11950, 1750, 26500]
# inside d
# [5, 4, 3, 6, 3]
# inside d
# [2013, 2015, 1998, 2003, 2014]
# inside d
# ['24.07.18', '16.08.18', '16.07.18', '20.07.18', '28.08.18']
# ['24.08.18', '07.10.18', '05.09.18', '29.10.18', '08.09.18']
# [3091.0, 3283.0, 3247.0, 1856.0, 490.0]
# inside d
# [123.0, 223.0, 265.0, 26.0, 20.0]
# inside d
# [30, 52, 51, 101, 12]
# inside d
# ['0.03780329990294403', '0.06792567773378008', '0.0816137973514013', '0.014008620689655173', '0.04081632653061224']
# inside d
# Successfully set the datatypes
# 0       2013-01-01
# 1       2015-01-01
# 2       1998-01-01
# 3       2003-01-01
# 4       2014-01-01
#            ...
# 78210   2014-01-01
# 78211   2006-01-01
# 78212   2014-01-01
# 78213   2011-01-01
# 78214   2018-01-01
# Name: first_registration_year, Length: 78215, dtype: datetime64[ns]

# %%
final_df.dtypes
# Out:
# product_tier                       object
# make_name                          object
# price                             float64
# first_zip_digit                   float64
# first_registration_year    datetime64[ns]
# created_date               datetime64[ns]
# deleted_date               datetime64[ns]
# search_views                      float64
# detail_views                      float64
# stock_days                        float64
# ctr                               float64
# dtype: object

# %%
final_df
# Out:
#       product_tier      make_name    price  first_zip_digit  \
# 0            Basic     Mitsubishi  16750.0              5.0
# 1            Basic  Mercedes-Benz  35950.0              4.0
# 2            Basic  Mercedes-Benz  11950.0              3.0
# 3            Basic           Ford   1750.0              6.0
# 4            Basic  Mercedes-Benz  26500.0              3.0
# ...            ...            ...      ...              ...
# 78210        Basic          Lexus  15740.0              8.0
# 78211        Basic        Hyundai   2950.0              6.0
# 78212        Basic     Volkswagen   7850.0              8.0
# 78213        Basic         Toyota  13945.0              5.0
# 78214        Basic     Volkswagen  38800.0              7.0
#
#       first_registration_year created_date deleted_date  search_views  \
# 0                  2013-01-01   2018-07-24   2018-08-24        3091.0
# 1                  2015-01-01   2018-08-16   2018-10-07        3283.0
# 2                  1998-01-01   2018-07-16   2018-09-05        3247.0
# 3                  2003-01-01   2018-07-20   2018-10-29        1856.0
# 4                  2014-01-01   2018-08-28   2018-09-08         490.0
# ...                       ...          ...          ...           ...
# 78210              2014-01-01   2018-07-12   2018-10-19        6895.0
# 78211              2006-01-01   2018-09-28   2018-10-23        1175.0
# 78212              2014-01-01   2018-11-04   2018-11-21         448.0
# 78213              2011-01-01   2018-09-04   2018-10-02        1617.0
# 78214              2018-01-01   2018-08-08   2018-08-09          55.0
#
#        detail_views  stock_days       ctr
# 0             123.0        30.0  0.037803
# 1             223.0        52.0  0.067926
# 2             265.0        51.0  0.081614
# 3              26.0       101.0  0.014009
# 4              20.0        12.0  0.040816
# ...             ...         ...       ...
# 78210         230.0        99.0  0.033358
# 78211          16.0        25.0  0.012936
# 78212          21.0        16.0  0.046875
# 78213          29.0        28.0  0.017934
# 78214           2.0         1.0  0.034545
#
# [78215 rows x 11 columns]

# %%
## Get Rid of the first_registration_year > 2020

# Store the indexes which have incorrect year into a list
z = (final_df[final_df['first_registration_year'].dt.year > 2020].index).tolist()
final_df = final_df.drop(index=z[0])


## Let us pickle out final dataframe so we do not have to re-run entire notebook
# File_1.pickle contains outliers
pickle_out = r'/Users/rohankumar/Desktop/AutoScout24/Case Study/Data/pickle/file_1.pickle'
pl = open(pickle_out, "wb")
pickle.dump(final_df, pl)

# %% [markdown]
# ### 5 Outlier Detection and Removal

# %%
final_df.describe()
# Out:
#                price  first_zip_digit   search_views  detail_views  \
# count   78214.000000     78214.000000   78214.000000  78214.000000
# mean    15071.593449         4.632227    2298.190222     93.507722
# std     16381.051105         2.354465    6341.342570    228.127119
# min        50.000000         1.000000       1.000000      0.000000
# 25%      5750.000000         3.000000     368.000000     13.000000
# 50%     10910.000000         5.000000     920.000000     36.000000
# 75%     18890.000000         7.000000    2234.000000     94.000000
# max    249888.000000         9.000000  608754.000000  13926.000000
#
#          stock_days           ctr
# count  78214.000000  78214.000000
# mean      35.989848      0.047920
# std       32.209401      0.327365
# min       -3.000000      0.000000
# 25%       10.000000      0.024094
# 50%       25.000000      0.037923
# 75%       55.000000      0.058201
# max      127.000000     87.500000

# %% [markdown]
# <p>The above dataset description clearly shows:
#     <ol>
#         <li><b>Price : </b>The max is significantly higher than the 0.75 Quantile. This means that we need to inspect using boxplot and eliminate outliers.
#         </li>
#         <li><b>Search Views :</b>The max search views is very high compared to the 0.75 quantile. Again, we need to inspect for ouliers using box plot and remove them. </li>
#     </ol>
# </p>

# %% [markdown]
# #### 5.1 Exploring the price feature

# %%
price_range_0_50 = [0, 50]
price_range_50_100 = [50, 100]
price_range_100_200 = [100, 200]
price_range_200_300 = [200, 300]
price_range_300_400 = [300, 400]
price_range_400_500 = [400, 500]
price_range_500_600 = [500, 600]

price_range_100000_200000 = [100000, 200000]
price_range_200000_300000 = [200000, 300000]


price_ranges = [price_range_0_50, price_range_50_100, price_range_100_200, price_range_200_300,
                price_range_300_400, price_range_400_500, price_range_500_600,
               price_range_100000_200000, price_range_200000_300000]

for price_range in price_ranges:
    print('Total number of vehicles sold between {}€ and {}€ are {}'.format(price_range[0],price_range[1],
        (final_df[(final_df.price >= price_range[0]) & (final_df.price<= price_range[1])].price.count())))
# Out:
# Total number of vehicles sold between 0€ and 50€ are 8
# Total number of vehicles sold between 50€ and 100€ are 48
# Total number of vehicles sold between 100€ and 200€ are 49
# Total number of vehicles sold between 200€ and 300€ are 51
# Total number of vehicles sold between 300€ and 400€ are 105
# Total number of vehicles sold between 400€ and 500€ are 247
# Total number of vehicles sold between 500€ and 600€ are 215
# Total number of vehicles sold between 100000€ and 200000€ are 386
# Total number of vehicles sold between 200000€ and 300000€ are 34

# %%
## Distribution of price vs make-name

fig, ax = plt.subplots(figsize=(20,10))
ax = sns.boxplot(y=final_df['price'], x=final_df['make_name'], data=final_df)
ax.tick_params(labelrotation=90, labelsize=14)
plt.title('Distribution of Price vs Make Name')
plt.ylabel('Price', size=14)
plt.xlabel('Make Name', size=14)
# Out:
# Text(0.5, 0, 'Make Name')

# %% [markdown]
# <p>From the price vs make-name graph, we can see many outliers. It will be beneficial if we get rid of these outliers in the dataset. To do this, there are two methods namely:</p>
#
# <ol>
#     <li>Z-Score</li>
#     <li>IQR</li>
# </ol>
#
# <p>I will be using IQR since it is more robust for outliers. I have tried using Z-score but did not find the results promising.</p>

# %%
## Remove using IQR
Q1 = final_df['price'].quantile(0.25)
Q3 = final_df['price'].quantile(0.75)
IQR = Q3 - Q1    #IQR is interquartile range. 

filter = (final_df['price'] >= Q1 - 1.5 * IQR) & (final_df['price'] <= Q3 + 1.5 *IQR)
final_df_copy = final_df.loc[filter] 
final_df_copy.describe()
# Out:
#               price  first_zip_digit   search_views  detail_views  \
# count  73611.000000     73611.000000   73611.000000  73611.000000
# mean   12062.400986         4.649278    2244.800084     90.871242
# std     8567.198426         2.353671    6394.460552    227.094695
# min       50.000000         1.000000       1.000000      0.000000
# 25%     5440.000000         3.000000     358.000000     13.000000
# 50%     9950.000000         5.000000     891.000000     35.000000
# 75%    16925.000000         7.000000    2156.000000     91.000000
# max    38548.000000         9.000000  608754.000000  13926.000000
#
#          stock_days           ctr
# count  73611.000000  73611.000000
# mean      35.592887      0.048046
# std       32.070553      0.337330
# min       -3.000000      0.000000
# 25%       10.000000      0.024029
# 50%       25.000000      0.037841
# 75%       54.000000      0.058281
# max      127.000000     87.500000

# %%
## After Outlier removal in Price feature

## Plot of Price vs Make-Name
fig, ax = plt.subplots(figsize=(20,10))
ax = sns.boxplot(y=final_df_copy['price'], x=final_df_copy['make_name'], data=final_df_copy)
ax.tick_params(labelrotation=90, labelsize=14)
plt.title('Distribution of Price vs Make Name after outlier removal')
plt.ylabel('Price', size=14)
plt.xlabel('Make Name', size=14)
# Out:
# Text(0.5, 0, 'Make Name')

# %%
## Scatterplot for price vs Make-Name
fig, ax = plt.subplots(figsize=(20,10))
ax = sns.scatterplot(y=final_df_copy['price'], x=final_df_copy['make_name'], data=final_df_copy)
ax.tick_params(labelrotation=90, labelsize=14)
plt.title('Distribution of Price vs Make Name after outlier removal')
plt.ylabel('Price', size=14)
plt.xlabel('Make Name', size=14)
# Out:
# Text(0.5, 0, 'Make Name')

# %% [markdown]
# #### 5.2 Exploring the Search-Views

# %%
fig, ax = plt.subplots(figsize=(20,10))
ax = sns.boxplot(y=final_df_copy['search_views'], x=final_df_copy['make_name'], data=final_df_copy)
ax.tick_params(labelrotation=90, labelsize=14)
plt.ylabel('Search Views', size=14)
plt.xlabel('Make Name', size=14)
# Out:
# Text(0.5, 0, 'Make Name')

# %% [markdown]
# <p>From the search-views vs make-name graph, we can see many outliers. It will be beneficial if we get rid of these outliers in the dataset. To do this, there are two methods namely:</p>
#
# <p>I will be using IQR since it is more robust for outliers.</p>

# %%
## Drop outlier in search views
## Remove using IQR
Q1 = final_df_copy['search_views'].quantile(0.25)
Q3 = final_df_copy['search_views'].quantile(0.75)
IQR = Q3 - Q1    #IQR is interquartile range. 

filter = (final_df_copy['search_views'] >= Q1 - 1.5 * IQR) & (final_df_copy['search_views'] <= Q3 + 1.5 *IQR)
final_df_copy = final_df_copy.loc[filter]
final_df_copy.describe()
# Out:
#               price  first_zip_digit  search_views  detail_views  \
# count  66575.000000     66575.000000  66575.000000  66575.000000
# mean   12224.432339         4.655862   1148.792550     51.225385
# std     8502.121736         2.354737   1097.999265     62.042964
# min       50.000000         1.000000      1.000000      0.000000
# 25%     5725.000000         3.000000    323.000000     11.000000
# 50%    10335.000000         5.000000    760.000000     30.000000
# 75%    16950.000000         7.000000   1635.000000     68.000000
# max    38548.000000         9.000000   4853.000000   1861.000000
#
#          stock_days           ctr
# count  66575.000000  66575.000000
# mean      32.193331      0.048909
# std       30.092814      0.354624
# min       -3.000000      0.000000
# 25%        9.000000      0.023873
# 50%       22.000000      0.038223
# 75%       48.000000      0.059375
# max      127.000000     87.500000

# %%
## Plot of Search-Views vs Make-Name
fig, ax = plt.subplots(figsize=(20,10))
ax = sns.boxplot(y=final_df_copy['search_views'], x=final_df_copy['make_name'], data=final_df_copy)
ax.tick_params(labelrotation=90, labelsize=14)
plt.title('Search-Views vs Make-Name')
plt.xlabel('Make Name', size=14)
plt.ylabel('Search Views', size=14)
# Out:
# Text(0, 0.5, 'Search Views')

# %%
## Plot of Detail-views vs Make-Name
fig, ax = plt.subplots(figsize=(20,10))
ax = sns.boxplot(y=final_df_copy['detail_views'], x=final_df_copy['make_name'], data=final_df_copy)
ax.tick_params(labelrotation=90, labelsize=14)
plt.title('Detail-Views vs Make-Name')
plt.xlabel('Make Name', size=14)
plt.ylabel('Detail Views', size=14)
# Out:
# Text(0, 0.5, 'Detail Views')

# %%
## Plot of make-name vs ctr
fig, ax = plt.subplots(figsize=(20,20))
ax = sns.lineplot(y=final_df_copy['ctr'], x=final_df_copy['make_name'], data=final_df_copy)
ax.tick_params(labelrotation=90, labelsize=14)
plt.title('Click-through-rate vs Make-Name')
plt.xlabel('Make Name', size=14)
plt.ylabel('Click-through-rate', size=14)
# Out:
# Text(0, 0.5, 'Click-through-rate')

# %%
fig, ax = plt.subplots(figsize=(20,20))
ax = sns.lineplot(y=final_df_copy['ctr'], x=final_df_copy['stock_days'], data=final_df_copy)
ax.tick_params(labelrotation=90, labelsize=14)
plt.title('Detail-Views vs Stock Days')
plt.ylabel('Detail-Views', size=14)
plt.xlabel('Stock Days', size=14)
# Out:
# Text(0.5, 0, 'Stock Days')

# %% [markdown]
# ### Pickle the Data

# %%
## Let us pickle out final dataframe so we do not have to re-run entire notebook
# File_1.pickle contains outliers
# File_2.pickle does not contain outliers
pickle_out = r'/Users/rohankumar/Desktop/AutoScout24/Case Study/Data/pickle/file_2.pickle'
pl = open(pickle_out, "wb")
pickle.dump(final_df_copy, pl)
